# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
dataf = pd.read_csv('pracone.csv')
dataf
# Out:
#    area    price
# 0   2600  550000
# 1   3000  565000
# 2   3200  610000
# 3   3600  680000
# 4   4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area')
plt.ylabel('Price')
# dataf.columns = dataf.columns.str.strip()
#i dont know sayed whitespace le agrda aayeko errror hunasakxa jaslai hatauna yo use vayo
plt.scatter(dataf.area,dataf.price,color='red',marker='*')
plt.plot(dataf.area,reg.predict(dataf[['area']]),color="green")
plt.show()

# %%
# print(dataf[['area']])
# print(dataf)
from sklearn.linear_model import LinearRegression
# reg =LinearRegression().fit(dataf[['area']],dataf.price)
reg

# %%
reg.predict([[3300]])
#i dont know yo pani 2d mai dinuparne rahexa purano yesto thiyena,
# y=mx+c anusar calculate gareko hunxa accuracy pani dherai hunxa

# %%
reg.coef_#m

# %%
reg.intercept_#b

# %%
135.78767123*3300 +180616.43835616432 #3300 vaneko x ko value

# %%
d= pd.read_csv('prac1.csv')

# %%
p=reg.predict(d)

# %%
d['prices']=p

# %%
d

# %%
d.to_csv("prediction.csv",index=False)#if you want to include index too

# %% [markdown]
# # Excercise

# %% [markdown]
# ### Per capita income prediction NEPAL

# %%
df= pd.read_csv('Nepalpci.csv')
df

# %%
df.PerCapita.head(5)

# %%
# %matplotlib inline
plt.figure(figsize=(9,6),dpi=100)

df.columns = pcidf.columns.str.strip()
plt.title("Per Capita income of nepal in USD",fontdict={"fontsize":20})
plt.scatter(df.date,df.PerCapita,color='red',marker='*')
plt.plot(df.date,reg.predict(df[['date']]),color="green")

plt.plot(df.date,df.PerCapita)
plt.show()

# %%
from sklearn.linear_model import LinearRegression


reg =LinearRegression().fit(df[['date']],df.PerCapita)
reg

# %%
reg.predict([[2020]])

# %%
reg.coef_#m

# %%
reg.intercept_#b

# %%
12.799*2020-25189.52 #y=mx+b

# %% [markdown]
# ## Bars

# %%
df.columns = pcidf.columns.str.strip()

plt.figure(figsize=(9,6),dpi=150)

plt.title("PCI rate according to year",fontdict={"fontsize":20})

plt.xlabel("Date")
plt.ylabel("Rate")


labels=df.date[::4]
values=df.Rate[::4]
bars= plt.bar(labels,values)
patterns= ['+','o','*','-','.','.','*','o','o','+','o','/','o','-','|']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
